# %% [markdown]
# # URLHAUS

# %%
import HWurlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'HWurlHaus' from 'c:\\Users\\dthom\\Documents\\SYS-320\\Week3\\Homework\\HWurlHaus.py'>

# %% [markdown]
# ## Video
#
# B. In your video, using the full dataset provided in the zip file, show:
# 1. Search for any domains that contain .edu and .gov.
# 2. Search for all URLS that contain .win32
# 3. Browse to the urlhaus.abuse.ch website that provides additional information about one link containing .win32.exe
# What did you like the most and least about this assignment?
# What additional questions do you have?

# %%
u.urlHausOpen('../../logs/urlHaus.csv', ["\.edu", "\.gov"])
# Out:
#             URL:hxxp://emtibuesp.gov.co/-/Q64DnjXKVg/
#             Info: https://urlhaus.abuse.ch/url/1911788/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://nms.gov.bz/voluptatibusodio/sedet-9689395
#             Info: https://urlhaus.abuse.ch/url/1870776/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://krusevo.gov.mk/update/ekologija/UbgpSdWbccCcY6MM/
#             Info: https://urlhaus.abuse.ch/url/1868933/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://hydromet.gov.bz/facerefacilis/essereiciendis-10302844
#             Info: https://urlhaus.abuse.ch/url/1863793/
# ...

# %%
 u.urlHausOpen('../../logs/urlHaus.csv', ["\.win32"])
# Out:
#             URL:hxxp://103.171.0.134/Registry/.win32.exe
#             Info: https://urlhaus.abuse.ch/url/2017874/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://198.46.132.195/Registry/.win32.exe
#             Info: https://urlhaus.abuse.ch/url/2017585/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://103.89.90.10/Registry/.win32.exe
#             Info: https://urlhaus.abuse.ch/url/2017583/
#             ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-
#
#             URL:hxxp://103.171.0.134/googleCRC/.win32.exe
#             Info: https://urlhaus.abuse.ch/url/2011286/
# ...

# %% [markdown]
# ### Homework
# 1. Provide the URL to the CSV documentation on the Python website.  Ensure you select the site with the appropriate version of Python you are using.
#
# https://docs.python.org/3.10/library/csv.html
#
# 2. What option is used if the default delimiter is not a comma? Write the full syntax.  Example csv.function(option=x, option2=y)
#
# reader = csv.reader(f, delimiter=':')
#
# 3. In a CSV file that uses a comma as a delimiter, there may be a field with a comma within it.  What option does Python provide to escape the comma within the text of a field so it is differentiated with the comma as a field delimiter?  Write the full syntax.  Example csv.function(option=x, option2=y)
#
# escapechar (not sure of the syntax as I was unable to find any examples and the wiki was confusing.)
#
# 4. What is the purpose of heredocs in Python?
#
# A heredoc is a way for python to specify a block of text, while keeping the formatting of the original text.
#
# https://rosettacode.org/wiki/Here_document#:~:text=A%20here%20document%20(or%20%22heredoc,other%20whitespace%20within%20the%20text.&text=You%20are%20encouraged%20to%20solve,any%20language%20you%20may%20know.
#
# (source)
